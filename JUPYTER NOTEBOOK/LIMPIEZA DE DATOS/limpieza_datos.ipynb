# %% [markdown]
# # Proyecto Integrador del curso de Analitica de datos - G7
#
# Integrantes:
# - Araujo Santillan, Pedro
# - Blas Ruiz, Luis
# - Lazaro Escobar, Vivian
# - Ramos Rivas, Kevin
# - Zenobio Pariasca, Alonso

# %% [markdown]
# ### Importancion de librerias

# %%
#Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importancion de datos

# %% [markdown]
# Los datos provienen de la plataforma de datos abiertos del gobierno de Peru, los datos son acerca de los proyectos de agua y saneamiento que se han realizado en el Peru desde ejecutados por diversas modaliades de ejecucion.
#
# - PROYECTOS DE INVERSIÓN EN LA MODALIDAD DE EJECUCIÓN DE NÚCLEO EJECUTOR-PNSR  [link 📒](https://www.datosabiertos.gob.pe/dataset/proyectos-de-inversi%C3%B3n-en-la-modalidad-de-ejecuci%C3%B3n-de-n%C3%BAcleo-ejecutor-pnsr-0)
#
# - PROYECTOS DE INVERSIÓN DEL ÁMBITO RURAL EJECUTADOS POR LOS GOBIERNOS SUB NACIONALES Y FINANCIADOS POR TRANSFERENCIA DE PARTIDAS-PNSR [link 📒](https://www.datosabiertos.gob.pe/dataset/proyectos-de-inversi%C3%B3n-del-%C3%A1mbito-rural-ejecutados-por-los-gobiernos-sub-nacionales-y-2)
#
# - PROYECTOS DE INVERSIÓN A EJECUTARSE EN LA MODALIDAD DE EJECUCIÓN DE OBRAS POR IMPUESTO (OXI)-PNSR [link 📒](https://www.datosabiertos.gob.pe/dataset/proyectos-de-inversi%C3%B3n-ejecutarse-en-la-modalidad-de-ejecuci%C3%B3n-de-obras-por-impuesto-oxi-2)

# %%
#Importar el dataset
df_por_impuestos = pd.read_excel('inversion_por_impuestos.xlsx')
df_por_impuestos.head()
# Out:
#    FECHA_CORTE  ITEM CODIGO_PAIS PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 0   20230724.0     1          PE     PNSR     344418.0         2305673.0
# 1   20230724.0     2          PE     PNSR     350013.0         2312883.0
# 2   20230724.0     3          PE     PNSR    2447108.0         2447108.0
# 3   20230724.0     4          PE     PNSR    2447183.0         2447183.0
# 4   20230724.0     5          PE     PNSR    2447188.0         2447188.0
#
#                                      NOMBRE_PROYECTO  \
# 0  INSTALACION DE LOS SERVICIOS DE AGUA POTABLE Y...
# 1  MEJORAMIENTO DEL SISTEMA DE SANEAMIENTO EN LA ...
# 2  CREACION DEL SERVICIO DE AGUA POTABLE  Y DISPO...
# 3  CREACION DEL SERVICIOS DE AGUA POTABLE Y DISPO...
# 4  CREACION DEL SERVICIO DE AGUA POTABLE Y DISPOS...
#
#                          UNIDAD_EJECUTORA DEPARTAMENTO          PROVINCIA  \
# 0  PROGRAMA NACIONAL DE SANEAMIENTO RURAL     MOQUEGUA     MARISCAL NIETO
# ...

# %%
#importar el dataset
df_por_nucleo = pd.read_excel('inversion_por_nucleo_ejecutor.xlsx')
df_por_nucleo.head()
# Out:
#    FECHA_CORTE  ITEM CODIGO_PAIS  \
# 0     20230724     1          PE
# 1     20230724     2          PE
# 2     20230724     3          PE
# 3     20230724     4          PE
# 4     20230724     5          PE
#
#                                         PROGRAMA  CODIGO_SNIP  \
# 0  PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       299528
# 1  PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       299634
# 2  PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       308260
# 3  PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       303322
# 4  PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       309623
#
#    CODIGO_UNIFICADO                                    NOMBRE_PROYECTO  \
# 0           2202459  INSTALACION DE LOS SERVICIOS DE AGUA POTABLE, ...
# 1           2235422  MEJORAMIENTO Y AMPLIACION DEL SERVICIO DE AGUA...
# 2           2305484  MEJORAMIENTO Y AMPLIACIÓN DEL SERVICIO DE AGUA...
# 3           2293850  MEJORAMIENTO Y AMPLIACION DEL SERVICIO DE AGUA...
# ...

# %%
df_por_subnac = pd.read_excel('inversion_por_subnacionales.xlsx')
df_por_subnac.head()
# Out:
#    FECHA_CORTE  ITEM CODIGO_PAIS PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 0     20230724     1          PE     PNSR       215882           2208926
# 1     20230724     2          PE     PNSR       257615           2177459
# 2     20230724     3          PE     PNSR       232101           2220981
# 3     20230724     4          PE     PNSR       185653           2215251
# 4     20230724     5          PE     PNSR       184846           2215250
#
#                                      NOMBRE_PROYECTO  \
# 0  INSTALACION DEL SERVICIO DE DESAGUE Y TRATAMIE...
# 1  INSTALACION DEL SISTEMA DE AGUA POTABLE Y DESA...
# 2  INSTALACION DEL SERVICIO DE SANEAMIENTO BASICO...
# 3  MEJORAMIENTO E INSTALACION DEL SERVICIO DE AGU...
# 4  MEJORAMIENTO E INSTALACION DEL SERVICIO DE AGU...
#
#                                UNIDAD_EJECUTORA DEPARTAMENTO  PROVINCIA  \
# 0       MUNICIPALIDAD DISTRITAL DE CHINCHA BAJA          ICA    CHINCHA
# ...

# %% [markdown]
# ### Hacemos un reporte de la cantidad de datos por cada dataset

# %%
df_por_impuestos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FECHA_CORTE               18 non-null     float64
#  1   ITEM                      19 non-null     int64
#  2   CODIGO_PAIS               18 non-null     object
#  3   PROGRAMA                  18 non-null     object
#  4   CODIGO_SNIP               18 non-null     float64
#  5   CODIGO_UNIFICADO          18 non-null     float64
#  6   NOMBRE_PROYECTO           18 non-null     object
#  7   UNIDAD_EJECUTORA          18 non-null     object
#  8   DEPARTAMENTO              18 non-null     object
#  9   PROVINCIA                 18 non-null     object
#  10  DISTRITO                  18 non-null     object
#  11  UBIGEO                    18 non-null     float64
#  12  BENEFICIARIOS             18 non-null     float64
# ...

# %%
df_por_nucleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FECHA_CORTE               594 non-null    int64
#  1   ITEM                      594 non-null    int64
#  2   CODIGO_PAIS               594 non-null    object
#  3   PROGRAMA                  594 non-null    object
#  4   CODIGO_SNIP               594 non-null    int64
#  5   CODIGO_UNIFICADO          594 non-null    int64
#  6   NOMBRE_PROYECTO           594 non-null    object
#  7   UNIDAD_EJECUTORA          594 non-null    object
#  8   DEPARTAMENTO              594 non-null    object
#  9   PROVINCIA                 594 non-null    object
#  10  DISTRITO                  594 non-null    object
#  11  UBIGEO                    594 non-null    int64
#  12  BENEFICIARIOS             594 non-null    int64
#  13  COSTO_TOTAL_INVERSION     594 non-null    float64
# ...

# %%
df_por_subnac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3337 entries, 0 to 3336
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FECHA_CORTE               3337 non-null   int64
#  1   ITEM                      3337 non-null   int64
#  2   CODIGO_PAIS               3337 non-null   object
#  3   PROGRAMA                  3337 non-null   object
#  4   CODIGO_SNIP               3337 non-null   int64
#  5   CODIGO_UNIFICADO          3337 non-null   int64
#  6   NOMBRE_PROYECTO           3337 non-null   object
#  7   UNIDAD_EJECUTORA          3337 non-null   object
#  8   DEPARTAMENTO              3337 non-null   object
#  9   PROVINCIA                 3337 non-null   object
#  10  DISTRITO                  3337 non-null   object
#  11  UBIGEO                    3337 non-null   int64
#  12  BENEFICIARIOS             3337 non-null   int64
# ...

# %% [markdown]
# ### Vemos la cantidad de datos por cada dataset

# %%
#creamos las columnas de un dataframe
df_cantidad_de_datos = pd.DataFrame(columns=['Dataset', 'Cantidad_de_datos'])

#agregamos los datos al dataframe
df_cantidad_de_datos = df_cantidad_de_datos.append({'Dataset': 'df_por_impuestos', 'Cantidad_de_datos': df_por_impuestos.shape[0]}, ignore_index=True)
df_cantidad_de_datos = df_cantidad_de_datos.append({'Dataset': 'df_por_nucleo', 'Cantidad_de_datos': df_por_nucleo.shape[0]}, ignore_index=True)
df_cantidad_de_datos = df_cantidad_de_datos.append({'Dataset': 'df_por_subnac', 'Cantidad_de_datos': df_por_subnac.shape[0]}, ignore_index=True)

#mostramos el dataframe
df_cantidad_de_datos
# Out:
# C:\Users\ramos\AppData\Local\Temp\ipykernel_23996\1564196285.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cantidad_de_datos = df_cantidad_de_datos.append({'Dataset': 'df_por_impuestos', 'Cantidad_de_datos': df_por_impuestos.shape[0]}, ignore_index=True)
# C:\Users\ramos\AppData\Local\Temp\ipykernel_23996\1564196285.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cantidad_de_datos = df_cantidad_de_datos.append({'Dataset': 'df_por_nucleo', 'Cantidad_de_datos': df_por_nucleo.shape[0]}, ignore_index=True)
# C:\Users\ramos\AppData\Local\Temp\ipykernel_23996\1564196285.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ### Tratamiento de datos

# %% [markdown]
# #### Dataset obras de saneamiento por impuestos

# %%
#buscamos los datos nulos
df_por_impuestos.isnull().sum()
# Out:
# FECHA_CORTE                  1
# ITEM                         0
# CODIGO_PAIS                  1
# PROGRAMA                     1
# CODIGO_SNIP                  1
# CODIGO_UNIFICADO             1
# NOMBRE_PROYECTO              1
# UNIDAD_EJECUTORA             1
# DEPARTAMENTO                 1
# PROVINCIA                    1
# DISTRITO                     1
# UBIGEO                       1
# BENEFICIARIOS                1
# COSTO_TOTAL_INVERSION        1
# MODALIDAD_FINANCIAMIENTO     1
# ETAPA                        1
# ESTADO                       1
# FECHA_INICIO                15
# FECHA_FIN                   16
# ESTADO_PIP_MEF               1
# dtype: int64

# %%
#vemos las filas que tienen datos nulos
df_por_impuestos[df_por_impuestos.isnull().any(axis=1)]
# Out:
#     FECHA_CORTE  ITEM CODIGO_PAIS PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 2    20230724.0     3          PE     PNSR    2447108.0         2447108.0
# 3    20230724.0     4          PE     PNSR    2447183.0         2447183.0
# 4    20230724.0     5          PE     PNSR    2447188.0         2447188.0
# 5    20230724.0     6          PE     PNSR    2447196.0         2447196.0
# 6    20230724.0     7          PE     PNSR    2447198.0         2447198.0
# 7    20230724.0     8          PE     PNSR    2447199.0         2447199.0
# 8    20230724.0     9          PE     PNSR    2447214.0         2447214.0
# 9    20230724.0    10          PE     PNSR    2447257.0         2447257.0
# 10   20230724.0    11          PE     PNSR    2447269.0         2447269.0
# 11   20230724.0    12          PE     PNSR    2449698.0         2449698.0
# 12   20230724.0    13          PE     PNSR    2450141.0         2450141.0
# 13   20230724.0    14          PE     PNSR    2450509.0         2450509.0
# ...

# %%
#si es que hay alguna fila con la columna FECHA_INICIO no nula y con la columna FECHA_FIN nula, entonces se reemplaza el valor de FECHA_FIN por el valor de la fecha actual(solo la fecha)
df_por_impuestos.loc[(df_por_impuestos['FECHA_INICIO'].notnull()) & (df_por_impuestos['FECHA_FIN'].isnull()), 'FECHA_FIN'] = pd.to_datetime('today').date()
#eliminamos las filas que tienen datos nulos
df_por_impuestos = df_por_impuestos.dropna()
df_por_impuestos.isnull().sum()
# Out:
# FECHA_CORTE                 0
# ITEM                        0
# CODIGO_PAIS                 0
# PROGRAMA                    0
# CODIGO_SNIP                 0
# CODIGO_UNIFICADO            0
# NOMBRE_PROYECTO             0
# UNIDAD_EJECUTORA            0
# DEPARTAMENTO                0
# PROVINCIA                   0
# DISTRITO                    0
# UBIGEO                      0
# BENEFICIARIOS               0
# COSTO_TOTAL_INVERSION       0
# MODALIDAD_FINANCIAMIENTO    0
# ETAPA                       0
# ESTADO                      0
# FECHA_INICIO                0
# FECHA_FIN                   0
# ESTADO_PIP_MEF              0
# dtype: int64

# %%
df_por_impuestos
# Out:
#     FECHA_CORTE  ITEM CODIGO_PAIS PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 0    20230724.0     1          PE     PNSR     344418.0         2305673.0
# 1    20230724.0     2          PE     PNSR     350013.0         2312883.0
# 14   20230724.0    15          PE     PNSR     376847.0         2337923.0
# 16   20230724.0    17          PE     PNSR    2497437.0         2497437.0
#
#                                       NOMBRE_PROYECTO  \
# 0   INSTALACION DE LOS SERVICIOS DE AGUA POTABLE Y...
# 1   MEJORAMIENTO DEL SISTEMA DE SANEAMIENTO EN LA ...
# 14  CREACION DE UNIDADES BÁSICAS DE SANEAMIENTO EN...
# 16  MEJORAMIENTO Y AMPLIACION DEL SERVICIO DE AGUA...
#
#                           UNIDAD_EJECUTORA DEPARTAMENTO       PROVINCIA  \
# 0   PROGRAMA NACIONAL DE SANEAMIENTO RURAL     MOQUEGUA  MARISCAL NIETO
# 1   PROGRAMA NACIONAL DE SANEAMIENTO RURAL        CUSCO           CUSCO
# 14  PROGRAMA NACIONAL DE SANEAMIENTO RURAL    CAJAMARCA       HUALGAYOC
# ...

# %% [markdown]
# #### Dataset obras de saneamiento por núcleo ejecutor

# %%
#buscamos los datos nulos
df_por_nucleo.isnull().sum()
# Out:
# FECHA_CORTE                  0
# ITEM                         0
# CODIGO_PAIS                  0
# PROGRAMA                     0
# CODIGO_SNIP                  0
# CODIGO_UNIFICADO             0
# NOMBRE_PROYECTO              0
# UNIDAD_EJECUTORA             0
# DEPARTAMENTO                 0
# PROVINCIA                    0
# DISTRITO                     0
# UBIGEO                       0
# BENEFICIARIOS                0
# COSTO_TOTAL_INVERSION        0
# MODALIDAD_FINANCIAMIENTO     0
# ETAPA                        0
# ESTADO                       0
# FECHA_INICIO                 4
# FECHA_FIN                   24
# ESTADO_PIP_MEF               0
# dtype: int64

# %%
#vemos las filas que tienen datos nulos
df_por_nucleo[df_por_nucleo.isnull().any(axis=1)]
# Out:
#      FECHA_CORTE  ITEM CODIGO_PAIS  \
# 21      20230724    22          PE
# 59      20230724    60          PE
# 257     20230724   258          PE
# 290     20230724   291          PE
# 313     20230724   314          PE
# 325     20230724   326          PE
# 336     20230724   337          PE
# 339     20230724   340          PE
# 340     20230724   341          PE
# 372     20230724   373          PE
# 373     20230724   374          PE
# 397     20230724   398          PE
# 446     20230724   447          PE
# 450     20230724   451          PE
# 457     20230724   458          PE
# 463     20230724   464          PE
# 464     20230724   465          PE
# 467     20230724   468          PE
# 473     20230724   474          PE
# 474     20230724   475          PE
# 487     20230724   488          PE
# 508     20230724   509          PE
# 509     20230724   510          PE
# 512     20230724   513          PE
#
#                                           PROGRAMA  CODIGO_SNIP  \
# ...

# %%
#si es que hay alguna fila con la columna FECHA_INICIO no nula y con la columna FECHA_FIN nula, entonces se reemplaza el valor de FECHA_FIN por el valor de la fecha actual(solo la fecha)
df_por_nucleo.loc[(df_por_nucleo['FECHA_INICIO'].notnull()) & (df_por_nucleo['FECHA_FIN'].isnull()), 'FECHA_FIN'] = pd.to_datetime('today').date()
#eliminamos las filas que tienen datos nulos
df_por_nucleo = df_por_nucleo.dropna()
df_por_nucleo.isnull().sum()
# Out:
# FECHA_CORTE                 0
# ITEM                        0
# CODIGO_PAIS                 0
# PROGRAMA                    0
# CODIGO_SNIP                 0
# CODIGO_UNIFICADO            0
# NOMBRE_PROYECTO             0
# UNIDAD_EJECUTORA            0
# DEPARTAMENTO                0
# PROVINCIA                   0
# DISTRITO                    0
# UBIGEO                      0
# BENEFICIARIOS               0
# COSTO_TOTAL_INVERSION       0
# MODALIDAD_FINANCIAMIENTO    0
# ETAPA                       0
# ESTADO                      0
# FECHA_INICIO                0
# FECHA_FIN                   0
# ESTADO_PIP_MEF              0
# dtype: int64

# %%
df_por_nucleo
# Out:
#      FECHA_CORTE  ITEM CODIGO_PAIS  \
# 0       20230724     1          PE
# 1       20230724     2          PE
# 2       20230724     3          PE
# 3       20230724     4          PE
# 4       20230724     5          PE
# ..           ...   ...         ...
# 589     20230724   590          PE
# 590     20230724   591          PE
# 591     20230724   592          PE
# 592     20230724   593          PE
# 593     20230724   594          PE
#
#                                           PROGRAMA  CODIGO_SNIP  \
# 0    PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       299528
# 1    PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       299634
# 2    PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       308260
# 3    PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       303322
# 4    PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       309623
# ..                                             ...          ...
# 589  PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR       295704
# ...

# %% [markdown]
# #### Dataset obras de saneamiento por sub nacional

# %%
#buscamos los datos nulos
df_por_subnac.isnull().sum()
# Out:
# FECHA_CORTE                   0
# ITEM                          0
# CODIGO_PAIS                   0
# PROGRAMA                      0
# CODIGO_SNIP                   0
# CODIGO_UNIFICADO              0
# NOMBRE_PROYECTO               0
# UNIDAD_EJECUTORA              0
# DEPARTAMENTO                  0
# PROVINCIA                     0
# DISTRITO                      0
# UBIGEO                        0
# BENEFICIARIOS                 0
# COSTO_TOTAL_INVERSION         2
# MODALIDAD_FINANCIAMIENTO      0
# ETAPA                         0
# ESTADO                        0
# FECHA_INICIO                 98
# FECHA_FIN                   418
# ESTADO_PIP_MEF                0
# dtype: int64

# %%
#vemos las filas que tienen datos nulos
df_por_subnac[df_por_subnac.isnull().any(axis=1)]
# Out:
#       FECHA_CORTE  ITEM CODIGO_PAIS PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 7        20230724     8          PE     PNSR       205078           2208858
# 8        20230724     9          PE     PNSR       182588           2212968
# 56       20230724    57          PE     PNSR       204244           2215742
# 133      20230724   134          PE     PNSR       208713           2153637
# 136      20230724   137          PE     PNSR       204391           2209190
# ...           ...   ...         ...      ...          ...               ...
# 3332     20230724  3333          PE     PNSR      2517213           2517213
# 3333     20230724  3334          PE     PNSR       255033           2176358
# 3334     20230724  3335          PE     PNSR       365499           2329163
# 3335     20230724  3336          PE     PNSR      2504004           2504004
# 3336     20230724  3337          PE     PNSR      2500475           2500475
#
# ...

# %%
#si es que hay alguna fila con la columna FECHA_INICIO no nula y con la columna FECHA_FIN nula, entonces se reemplaza el valor de FECHA_FIN por el valor de la fecha actual(solo la fecha)
df_por_subnac.loc[(df_por_subnac['FECHA_INICIO'].notnull()) & (df_por_subnac['FECHA_FIN'].isnull()), 'FECHA_FIN'] = pd.to_datetime('today').date()
#eliminamos las filas que tienen datos nulos
df_por_subnac = df_por_subnac.dropna()
df_por_subnac.isnull().sum()
# Out:
# FECHA_CORTE                 0
# ITEM                        0
# CODIGO_PAIS                 0
# PROGRAMA                    0
# CODIGO_SNIP                 0
# CODIGO_UNIFICADO            0
# NOMBRE_PROYECTO             0
# UNIDAD_EJECUTORA            0
# DEPARTAMENTO                0
# PROVINCIA                   0
# DISTRITO                    0
# UBIGEO                      0
# BENEFICIARIOS               0
# COSTO_TOTAL_INVERSION       0
# MODALIDAD_FINANCIAMIENTO    0
# ETAPA                       0
# ESTADO                      0
# FECHA_INICIO                0
# FECHA_FIN                   0
# ESTADO_PIP_MEF              0
# dtype: int64

# %%
df_por_subnac
# Out:
#       FECHA_CORTE  ITEM CODIGO_PAIS PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 0        20230724     1          PE     PNSR       215882           2208926
# 1        20230724     2          PE     PNSR       257615           2177459
# 2        20230724     3          PE     PNSR       232101           2220981
# 3        20230724     4          PE     PNSR       185653           2215251
# 4        20230724     5          PE     PNSR       184846           2215250
# ...           ...   ...         ...      ...          ...               ...
# 3309     20230724  3310          PE     PNSR      2516214           2516214
# 3311     20230724  3312          PE     PNSR      2520188           2520188
# 3312     20230724  3313          PE     PNSR      2520457           2520457
# 3313     20230724  3314          PE     PNSR      2524149           2524149
# 3314     20230724  3315          PE     PNSR      2520939           2520939
#
# ...

# %% [markdown]
# #### Unión de los datasets

# %%
# union de los 3 dataframes
df = pd.concat([df_por_impuestos, df_por_nucleo, df_por_subnac], ignore_index=True)
df
# Out:
#       FECHA_CORTE  ITEM CODIGO_PAIS  \
# 0      20230724.0     1          PE
# 1      20230724.0     2          PE
# 2      20230724.0    15          PE
# 3      20230724.0    17          PE
# 4      20230724.0     1          PE
# ...           ...   ...         ...
# 3827   20230724.0  3310          PE
# 3828   20230724.0  3312          PE
# 3829   20230724.0  3313          PE
# 3830   20230724.0  3314          PE
# 3831   20230724.0  3315          PE
#
#                                            PROGRAMA  CODIGO_SNIP  \
# 0                                              PNSR     344418.0
# 1                                              PNSR     350013.0
# 2                                              PNSR     376847.0
# 3                                              PNSR    2497437.0
# 4     PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR     299528.0
# ...                                             ...          ...
# 3827                                           PNSR    2516214.0
# ...

# %% [markdown]
# #### Eliminación de columnas y reemplazo de valores

# %% [markdown]
# Vemos que la columna fecha_corte es repetitiva y no nos aporta nada, por lo que la eliminamos

# %% [markdown]
# ##### ITEM

# %%
#vemos que la columna ITEM no aporta informacion relevante
df = df.drop(['ITEM'], axis=1)

# %% [markdown]
# ##### FECHA_CORTE

# %%
#eliminamos las columna fecha_corte no es necesaria
df = df.drop(['FECHA_CORTE'], axis=1)

# %% [markdown]
# ##### PROGRAMA

# %% [markdown]
# Como se puede apreciar a continuacion, la columna PROGRAMA cuenta con solo 2 valores que al final son lo mismo, por lo que se decide ser reemplzada por el string
# "PNSR"

# %%
#vemos los valores de la columna PROGRAMA
df['PROGRAMA'].value_counts()
# Out:
# PNSR                                             3242
# PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR     590
# Name: PROGRAMA, dtype: int64

# %%
#reemplazamos los valores de la columna PROGRAMA por "PNSR"
df['PROGRAMA'] = df['PROGRAMA'].replace(['PROGRAMA NACIONAL DE SANEAMIENTO RURAL - PNSR'], 'PNSR')

# %% [markdown]
# ##### PAIS

# %%
#eliminación de la columna PAIS
df = df.drop(['CODIGO_PAIS'], axis=1)

# %% [markdown]
# ##### NOMBRE_PROYECTO, UNIDAD EJECUTORA, DEPARTAMENTO, PROVINCIA, DISTRITO, MODALIDAD_FINANCIAMIENTO,	ETAPA,ESTADO Y ESTADO_PIP_MEF

# %%
#CONVERTIR LAS COLUMNAS NOMBRE_PROYECTO, UNIDAD EJECUTORA, DEPARTAMENTO, PROVINCIA, DISTRITO, MODALIDAD_FINANCIAMIENTO,	ETAPA,ESTADO ,ESTADO_PIP_MEF A MAYUSCULAS
df['NOMBRE_PROYECTO'] = df['NOMBRE_PROYECTO'].str.upper()
df['UNIDAD_EJECUTORA'] = df['UNIDAD_EJECUTORA'].str.upper()
df['DEPARTAMENTO'] = df['DEPARTAMENTO'].str.upper()
df['PROVINCIA'] = df['PROVINCIA'].str.upper()
df['DISTRITO'] = df['DISTRITO'].str.upper()
df['MODALIDAD_FINANCIAMIENTO'] = df['MODALIDAD_FINANCIAMIENTO'].str.upper()
df['ETAPA'] = df['ETAPA'].str.upper()
df['ESTADO'] = df['ESTADO'].str.upper()
df['ESTADO_PIP_MEF'] = df['ESTADO_PIP_MEF'].str.upper()

# %% [markdown]
# ##### FECHA_INICIO y FECHA_FIN

# %%
#hacemos una funcion que convierta los valores de la columnas FECHA_INICIO y FECHA_FIN a formato fecha dependiendo de su formato
def convertir_fecha(fecha):
    if type(fecha) == str:
        if fecha.find('/') != -1:
            return pd.to_datetime(fecha, format='%Y-%m-%d').date()
        elif fecha.find('-') != -1:
            return pd.to_datetime(fecha, format='%Y-%m-%d').date()
    elif type(fecha) == int:
        return pd.to_datetime(fecha, format='%Y%m%d').date()
    elif type(fecha) == float:
        return pd.to_datetime(fecha, format='%Y%m%d').date()
    elif type(fecha) == pd._libs.tslibs.timestamps.Timestamp:
        return fecha.date()
    else:
        return fecha

# %%
#aplicamos la funcion a las columnas FECHA_INICIO y FECHA_FIN
df['FECHA_INICIO'] = df['FECHA_INICIO'].apply(convertir_fecha)
df['FECHA_FIN'] = df['FECHA_FIN'].apply(convertir_fecha)

# %% [markdown]
# ##### UBIGEO
# El ubigeo es un codigo que identifica a cada departamento, provincia y distrito del Peru, por lo que se debe ser entero

# %%
#convertimos la columna UBIGEO a entero
df['UBIGEO'] = df['UBIGEO'].astype(int)

# %% [markdown]
# ##### CODIGO_SNIP, CODIGO_UNIFICADO
#
# Ambas al ser columnas de codigos se deben ser enteros, por lo que se procede a convertirlos

# %%
#convertimos las columnas CODIGO_SNIP y CODIGO_UNIFICADO a entero
df['CODIGO_SNIP'] = df['CODIGO_SNIP'].astype(int)
df['CODIGO_UNIFICADO'] = df['CODIGO_UNIFICADO'].astype(int)

# %% [markdown]
# ##### BENEFICIARIOS
#
# La columna beneficiarios nos indica la cantidad de beneficiarios que se veran afectados por el proyecto, por lo que se debe ser entero

# %%
#convertimos la columna BENEFICIARIOS a entero
df['BENEFICIARIOS'] = df['BENEFICIARIOS'].astype(int)

# %% [markdown]
# #### Verificamos como quedo el dataset

# %%
df
# Out:
#      PROGRAMA  CODIGO_SNIP  CODIGO_UNIFICADO  \
# 0        PNSR       344418           2305673
# 1        PNSR       350013           2312883
# 2        PNSR       376847           2337923
# 3        PNSR      2497437           2497437
# 4        PNSR       299528           2202459
# ...       ...          ...               ...
# 3827     PNSR      2516214           2516214
# 3828     PNSR      2520188           2520188
# 3829     PNSR      2520457           2520457
# 3830     PNSR      2524149           2524149
# 3831     PNSR      2520939           2520939
#
#                                         NOMBRE_PROYECTO  \
# 0     INSTALACION DE LOS SERVICIOS DE AGUA POTABLE Y...
# 1     MEJORAMIENTO DEL SISTEMA DE SANEAMIENTO EN LA ...
# 2     CREACION DE UNIDADES BÁSICAS DE SANEAMIENTO EN...
# 3     MEJORAMIENTO Y AMPLIACION DEL SERVICIO DE AGUA...
# 4     INSTALACION DE LOS SERVICIOS DE AGUA POTABLE, ...
# ...                                                 ...
# ...

# %% [markdown]
# #### Exportamos el dataset

# %%
#Exportamos el dataframe a un archivo CSV
df.to_csv('inversion_publica_limpia.csv', index=False)
